# %% [markdown]
# # Project-2 Data acquisition and Data Wrangling

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %% [markdown]
# # Task 1: Data acquisition and Data Wrangling dts1,2

# %% [markdown]
# # import dataset 1

# %%
data1 = pd.read_csv('dataset_1.csv') #Library action

# %%
data1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %% [markdown]
# # Shape of dataset1

# %%
data1.shape  #number of rows & column
# Out:
# (610, 10)

# %%
data1.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %%
data1.shape[0]  #number of rows
# Out:
# 610

# %%
data1.shape[1]  #number of columns
# Out:
# 10

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=610, step=1)

# %%
data1.head() # by default first five rows
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
data1.tail() # by default last five rows
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
data1.sample(5)  #display the random five rows
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 48        49  03-01-2011       1   0     1   1    False        1           1
# 312      313  14-01-2011       1   0     1  12    False        5           1
# 198      199  09-01-2011       1   0     1  13    False        0           1
# 516      517  23-01-2011       1   0     1  15    False        0           1
# 565      566  25-01-2011       1   0     1  18    False        2           2
#
#      temp
# 48   0.20
# 312  0.20
# 198  0.20
# 516  0.16
# 565  0.30

# %%
data1.isnull().sum()   # check the null value
# Out:
# instant             0
# date of the ride    0
# season              0
# yr                  0
# mnth                0
# hr                  0
# holiday             0
# weekday             0
# weathersit          0
# temp                0
# dtype: int64

# %%
data1.nunique() #check unique value
# Out:
# instant       610
# dteday         28
# season          1
# yr              1
# mnth            1
# hr             24
# holiday         2
# weekday         7
# weathersit      4
# temp           23
# dtype: int64

# %%
df = pd.DataFrame(data1)

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df.loc[1:5,['dteday','temp']] #using loc function we r call 1 to 5 row & date ,temprature colummn
# Out:
#        dteday  temp
# 1  01-01-2011  0.22
# 2  01-01-2011  0.22
# 3  01-01-2011  0.24
# 4  01-01-2011  0.24
# 5  01-01-2011  0.24

# %%
df.iloc[1:5,[1,2,3]] #using iloc function we call 1 to 5 rows and date,season,year column called using indexing
# Out:
#        dteday  season  yr
# 1  01-01-2011       1   0
# 2  01-01-2011       1   0
# 3  01-01-2011       1   0
# 4  01-01-2011       1   0

# %%
df.iloc[:,:]    #all column & rows
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df.sort_values(by='weekday',ascending= False)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 490      491  22-01-2011       1   0     1  12    False        6           2
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 184      185  08-01-2011       1   0     1  23    False        6           1
# 183      184  08-01-2011       1   0     1  22    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 365      366  16-01-2011       1   0     1  17    False        0           1
# 366      367  16-01-2011       1   0     1  18    False        0           1
# 367      368  16-01-2011       1   0     1  19    False        0           1
# 368      369  16-01-2011       1   0     1  20    False        0           1
# 355      356  16-01-2011       1   0     1   7    False        0           2
#
#      temp
# 0    0.24
# 490  0.06
# ...

# %% [markdown]
# # datatype of dataset 1

# %%
df.info()   # information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %% [markdown]
# # Summary of dataset 1

# %%
df.describe().round(2)
# Out:
#        instant      hr
# count   610.00  610.00
# mean    305.50   11.80
# std     176.24    6.85
# min       1.00    0.00
# 25%     153.25    6.00
# 50%     305.50   12.00
# 75%     457.75   18.00
# max     610.00   23.00

# %%
# count---number of null values
#mean--- average value  
#std--variability
#min---minimum value
#25% ....first quartile
#50%----second quartile---median
#75% ---third quartile---
#max--- maximum value
#mean = sum of all values/number of values

# %%
df.describe().round(2)
# Out:
#        instant  season     yr   mnth      hr  weekday  weathersit    temp
# count   610.00   610.0  610.0  610.0  610.00   610.00      610.00  610.00
# mean    305.50     1.0    0.0    1.0   11.80     2.98        1.48    0.20
# std     176.24     0.0    0.0    0.0    6.85     2.05        0.64    0.08
# min       1.00     1.0    0.0    1.0    0.00     0.00        1.00    0.02
# 25%     153.25     1.0    0.0    1.0    6.00     1.00        1.00    0.16
# 50%     305.50     1.0    0.0    1.0   12.00     3.00        1.00    0.20
# 75%     457.75     1.0    0.0    1.0   18.00     5.00        2.00    0.24
# max     610.00     1.0    0.0    1.0   23.00     6.00        4.00    0.46

# %%
df[['instant','season','temp']]  #only requried coiumn
# Out:
#      instant  season  temp
# 0          1       1  0.24
# 1          2       1  0.22
# 2          3       1  0.22
# 3          4       1  0.24
# 4          5       1  0.24
# ..       ...     ...   ...
# 605      606       1  0.18
# 606      607       1  0.18
# 607      608       1  0.18
# 608      609       1  0.22
# 609      610       1  0.20
#
# [610 rows x 3 columns]

# %%
df_rand=data1.sample

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df.filter(like='a')
# Out:
#      instant      dteday  season  holiday  weekday  weathersit
# 0          1  01-01-2011       1    False        6           1
# 1          2  01-01-2011       1    False        6           1
# 2          3  01-01-2011       1    False        6           1
# 3          4  01-01-2011       1    False        6           1
# 4          5  01-01-2011       1    False        6           1
# ..       ...         ...     ...      ...      ...         ...
# 605      606  28-01-2011       1    False        5           3
# 606      607  28-01-2011       1    False        5           3
# 607      608  28-01-2011       1    False        5           3
# 608      609  28-01-2011       1    False        5           3
# 609      610  28-01-2011       1    False        5           2
#
# [610 rows x 6 columns]

# %%
df.filter(regex='[an]')
# Out:
#      instant      dteday  season  mnth  holiday  weekday  weathersit
# 0          1  01-01-2011       1     1    False        6           1
# 1          2  01-01-2011       1     1    False        6           1
# 2          3  01-01-2011       1     1    False        6           1
# 3          4  01-01-2011       1     1    False        6           1
# 4          5  01-01-2011       1     1    False        6           1
# ..       ...         ...     ...   ...      ...      ...         ...
# 605      606  28-01-2011       1     1    False        5           3
# 606      607  28-01-2011       1     1    False        5           3
# 607      608  28-01-2011       1     1    False        5           3
# 608      609  28-01-2011       1     1    False        5           3
# 609      610  28-01-2011       1     1    False        5           2
#
# [610 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, weathersit, temp]
# Index: []

# %% [markdown]
# # Date of the ride

# %%
df['dteday']
# Out:
# 0      01-01-2011
# 1      01-01-2011
# 2      01-01-2011
# 3      01-01-2011
# 4      01-01-2011
#           ...
# 605    28-01-2011
# 606    28-01-2011
# 607    28-01-2011
# 608    28-01-2011
# 609    28-01-2011
# Name: dteday, Length: 610, dtype: object

# %%
df.rename(columns = {'dteday' : 'Date of the ride'}, inplace = True)

# %%
df
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0          1       01-01-2011       1   0     1   0    False        6
# 1          2       01-01-2011       1   0     1   1    False        6
# 2          3       01-01-2011       1   0     1   2    False        6
# 3          4       01-01-2011       1   0     1   3    False        6
# 4          5       01-01-2011       1   0     1   4    False        6
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 605      606       28-01-2011       1   0     1  11    False        5
# 606      607       28-01-2011       1   0     1  12    False        5
# 607      608       28-01-2011       1   0     1  13    False        5
# 608      609       28-01-2011       1   0     1  14    False        5
# 609      610       28-01-2011       1   0     1  15    False        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# 3             1  0.24
# ...

# %%
df['season']= df['season'].replace({1:'Spring',2:'Summer',3:'fall',4:'Winter'})

# %%
df
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0    False        6
# 1          2       01-01-2011  Spring   0     1   1    False        6
# 2          3       01-01-2011  Spring   0     1   2    False        6
# 3          4       01-01-2011  Spring   0     1   3    False        6
# 4          5       01-01-2011  Spring   0     1   4    False        6
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 605      606       28-01-2011  Spring   0     1  11    False        5
# 606      607       28-01-2011  Spring   0     1  12    False        5
# 607      608       28-01-2011  Spring   0     1  13    False        5
# 608      609       28-01-2011  Spring   0     1  14    False        5
# 609      610       28-01-2011  Spring   0     1  15    False        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# 3             1  0.24
# ...

# %% [markdown]
# # unique value of season

# %%
df['season'].unique()
# Out:
# array(['Spring'], dtype=object)

# %% [markdown]
# # Whether day is consider a holiday

# %%
df['holiday'] = df['holiday'].replace({False:'Not a holiday'})

# %%
df
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a holiday        6
# 1          2       01-01-2011  Spring   0     1   1  Not a holiday        6
# 2          3       01-01-2011  Spring   0     1   2  Not a holiday        6
# 3          4       01-01-2011  Spring   0     1   3  Not a holiday        6
# 4          5       01-01-2011  Spring   0     1   4  Not a holiday        6
# ..       ...              ...     ...  ..   ...  ..            ...      ...
# 605      606       28-01-2011  Spring   0     1  11  Not a holiday        5
# 606      607       28-01-2011  Spring   0     1  12  Not a holiday        5
# 607      608       28-01-2011  Spring   0     1  13  Not a holiday        5
# 608      609       28-01-2011  Spring   0     1  14  Not a holiday        5
# 609      610       28-01-2011  Spring   0     1  15  Not a holiday        5
#
#      weathersit  temp
# 0             1  0.24
# ...

# %% [markdown]
# # Weekday

# %%
df['weekday'] = df['weekday'].apply(lambda x: 'working day' if x >= 6 else 'weekend or holiday')

# %%
df
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a holiday
#
#                 weekday  weathersit  temp
# 0           working day           1  0.24
# 1           working day           1  0.22
# ...

# %%
df['weekday'].unique()

# %% [markdown]
# # weather 1:clear,few,clouds,partly cloudy

# %%
df['weathersit']=df['weathersit'].replace({1:'clear,few,clouds,partly cloudy'})

# %%
df['weathersit']=df['weathersit'].replace({2:'Mist+cloudymist+broken clouds,mist +few clouds+mist'})

# %%
df['weathersit']=df['weathersit'].replace({3:'Light snow,Light Rain+Thounderstrom+Scatteredclouds,Light rain,+scattered clouds'})

# %%
df['weathersit']=df['weathersit'].replace({4:'Heavy rain+Ice pallets+Thounderstrome+mist snow+fog'})

# %%
df
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a holiday
#
#                 weekday                                         weathersit  \
# 0           working day                     clear,few,clouds,partly cloudy
# ...

# %% [markdown]
# # temp-'feelslike' temperature in Celsius

# %%
df['temp']
# Out:
# 0      0.24
# 1      0.22
# 2      0.22
# 3      0.24
# 4      0.24
#        ...
# 605    0.18
# 606    0.18
# 607    0.18
# 608    0.22
# 609    0.20
# Name: temp, Length: 610, dtype: float64

# %%
df['temp'] = df['temp'].apply(lambda x: f'{x} degree Celsius, feels like {int(x * 100)}')

# %%
df['temp']
# Out:
# 0      0.24 degree Celsius, feels like 24
# 1      0.22 degree Celsius, feels like 22
# 2      0.22 degree Celsius, feels like 22
# 3      0.24 degree Celsius, feels like 24
# 4      0.24 degree Celsius, feels like 24
#                       ...
# 605    0.18 degree Celsius, feels like 18
# 606    0.18 degree Celsius, feels like 18
# 607    0.18 degree Celsius, feels like 18
# 608    0.22 degree Celsius, feels like 22
# 609     0.2 degree Celsius, feels like 20
# Name: temp, Length: 610, dtype: object

# %%
df
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a holiday
#
#                 weekday                                         weathersit  \
# 0           working day                     clear,few,clouds,partly cloudy
# ...

# %% [markdown]
# # drop unnecessory column

# %%
df=df.drop(['yr','mnth'],axis=1)

# %%
df
# Out:
#      instant Date of the ride  season  hr        holiday             weekday  \
# 0          1       01-01-2011  Spring   0  Not a holiday         working day
# 1          2       01-01-2011  Spring   1  Not a holiday         working day
# 2          3       01-01-2011  Spring   2  Not a holiday         working day
# 3          4       01-01-2011  Spring   3  Not a holiday         working day
# 4          5       01-01-2011  Spring   4  Not a holiday         working day
# ..       ...              ...     ...  ..            ...                 ...
# 605      606       28-01-2011  Spring  11  Not a holiday  weekend or holiday
# 606      607       28-01-2011  Spring  12  Not a holiday  weekend or holiday
# 607      608       28-01-2011  Spring  13  Not a holiday  weekend or holiday
# 608      609       28-01-2011  Spring  14  Not a holiday  weekend or holiday
# 609      610       28-01-2011  Spring  15  Not a holiday  weekend or holiday
#
# ...

# %%
df.isnull().sum()
# Out:
# instant             0
# Date of the ride    0
# season              0
# hr                  0
# holiday             0
# weekday             0
# weathersit          0
# temp                0
# dtype: int64

# %% [markdown]
# # Dataset 2

# %%
data2=pd.read_csv('dataset_2.csv')

# %%
data2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df1 = pd.DataFrame(data2)

# %%
df1
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df1.describe().round(2)
# Out:
#        Unnamed: 0  instant   atemp     hum  windspeed  casual  registered  \
# count      610.00   610.00  599.00  610.00     610.00  610.00      610.00
# mean       304.50   305.50    0.20    0.56       0.20    4.50       51.07
# std        176.24   176.24    0.08    0.18       0.12    6.32       47.02
# min          0.00     1.00    0.00    0.21       0.00    0.00        0.00
# 25%        152.25   153.25    0.15    0.43       0.10    0.00       14.00
# 50%        304.50   305.50    0.20    0.52       0.19    2.00       43.00
# 75%        456.75   457.75    0.24    0.69       0.28    6.00       70.00
# max        609.00   610.00    0.45    1.00       0.58   47.00      247.00
#
#           cnt
# count  610.00
# mean    55.57
# std     49.32
# min      1.00
# 25%     16.00
# 50%     47.00
# 75%     79.75
# max    249.00

# %%
df1.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df1.tail()
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %%
df1.sample()
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 559         559      560  0.2879  0.56     0.0896      21          85  106

# %%
df1.nunique()
# Out:
# Unnamed: 0    610
# instant       610
# atemp          29
# hum            61
# windspeed      20
# casual         32
# registered    150
# cnt           165
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'instant', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df1['hum'] = df1['hum'].apply(lambda x: f'{int(x * 100)}%')

# %% [markdown]
# # central tendency of windspeed

# %%
df1['windspeed'].mean()
# Out:
# 0.20485098360655737

# %%
df1['windspeed'].median()
# Out:
# 0.194

# %%
df1['windspeed'].mode()
# Out:
# 0    0.1642
# Name: windspeed, dtype: float64

# %% [markdown]
# # unique values of non registered user rentals

# %%
df1['casual'].unique()
# Out:
# array([ 3,  8,  5,  0,  2,  1, 12, 26, 29, 47, 35, 40, 41, 15,  9,  6, 11,
#         4,  7, 16, 20, 19, 10, 13, 14, 18, 17, 21, 33, 23, 22, 24],
#       dtype=int64)

# %%
df1['casual'].mean()
# Out:
# 4.501639344262295

# %%
df1['casual'].median()
# Out:
# 2.0

# %%
df1['casual'].mode()
# Out:
# 0    0
# Name: casual, dtype: int64

# %% [markdown]
# # unique values of registered user rentals

# %%
df1['registered'].unique()
# Out:
# array([ 13,  32,  27,  10,   1,   0,   2,   7,   6,  24,  30,  55,  47,
#         71,  70,  52,  26,  31,  25,  17,  16,   8,   4,  19,  46,  54,
#         73,  64,  67,  58,  43,  29,  20,   9,   5,   3,  63, 153,  81,
#         33,  41,  48,  53,  66, 146, 148, 102,  49,  11,  36,  92, 177,
#         98,  37,  50,  79,  68, 202, 179, 110,  34,  87, 192, 109,  74,
#         65,  85, 186, 166, 127,  82,  40,  18,  95, 216, 116,  42,  57,
#         78,  59, 163, 158,  51,  76, 190, 125, 178,  39,  14,  15,  56,
#         60,  90,  83,  69,  28,  35,  22,  12,  77,  44,  38,  75, 184,
#        174, 154,  97, 214,  45,  72, 130,  94, 139, 135, 197, 137, 141,
#        156, 117, 155, 134,  89,  80, 108,  61, 124, 132, 196, 107, 100,
#        247, 140,  86,  62, 207, 210, 159, 151, 119,  93,  23, 171, 145,
#        101,  21, 103, 233, 208, 218, 133], dtype=int64)

# %% [markdown]
# # central tendency of registered user rentals

# %%
df1['registered'].mean()
# Out:
# 51.06885245901639

# %%
df1['registered'].median()
# Out:
# 43.0

# %%
df1['registered'].mode()
# Out:
# 0    1
# Name: registered, dtype: int64

# %% [markdown]
# # count-number of total rentals

# %% [markdown]
# # unique values of total rentals

# %%
df1['cnt'].unique()
# Out:
# array([ 16,  40,  32,  13,   1,   2,   3,   8,  14,  36,  56,  84,  94,
#        106, 110,  93,  67,  35,  37,  34,  28,  39,  17,   9,   6,  20,
#         53,  70,  75,  59,  74,  76,  65,  30,  22,  31,   5,  64, 154,
#         88,  44,  51,  61,  77,  72, 157,  52,  12,   4, 179, 100,  42,
#         57,  78,  97,  63,  83, 212, 182, 112,  54,  48,  11,  33, 195,
#        115,  46,  79,  71,  62,  89, 190, 169, 132,  43,  19,  95, 219,
#        122,  45,  86, 172, 163,  69,  23,   7, 210, 134,  73,  50,  87,
#        187, 123,  15,  25,  98, 102,  55,  10,  49,  82,  92,  41,  38,
#        188,  47, 178, 155,  24,  18,  27,  99, 217, 130, 136,  29, 128,
#         81,  68, 139, 137, 202,  60, 162, 144, 158, 117,  90, 159, 101,
#        118, 129,  26, 104,  91, 113, 105,  21,  80, 125, 133, 197, 109,
#        161, 249, 143, 215, 185, 152, 126, 166, 120,  96, 103,  58, 116,
#        177, 184, 153, 108, 238, 222, 225, 146, 119], dtype=int64)

# %%
df1['cnt'].mean()
# Out:
# 55.570491803278685

# %%
df1['cnt'].median()
# Out:
# 47.0

# %%
df1['cnt'].mode()
# Out:
# 0    1
# Name: cnt, dtype: int64

# %%
df1.rename(columns={'cnt':'Total rentals'}, inplace=True)

# %% [markdown]
# # Missing values of dataset 2

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0        0
# instant           0
# atemp            11
# hum               0
# windspeed         0
# casual            0
# registered        0
# Total rentals     0
# dtype: int64

# %%
df1['atemp'].mean()
# Out:
# 0.19993489148580967

# %%
df1['atemp'].fillna(df1['atemp'].mean(), inplace=True)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0       0
# instant          0
# atemp            0
# hum              0
# windspeed        0
# casual           0
# registered       0
# Total rentals    0
# dtype: int64

# %% [markdown]
# # Dropping unnecessary columns

# %%
df1.drop('Unnamed: 0',axis=1, inplace = True)

# %%
df1
# Out:
#      instant   atemp  hum  windspeed  casual  registered  Total rentals
# 0          1  0.2879  81%     0.0000       3          13             16
# 1          2  0.2727  80%     0.0000       8          32             40
# 2          3  0.2727  80%     0.0000       5          27             32
# 3          4  0.2879  75%     0.0000       3          10             13
# 4          5  0.2879  75%     0.0000       0           1              1
# ..       ...     ...  ...        ...     ...         ...            ...
# 605      606  0.2121  93%     0.1045       0          30             30
# 606      607  0.2121  93%     0.1045       1          28             29
# 607      608  0.2121  93%     0.1045       0          31             31
# 608      609  0.2727  80%     0.0000       2          36             38
# 609      610  0.2576  86%     0.0000       1          40             41
#
# [610 rows x 7 columns]

# %% [markdown]
# ## Merge  Dataset 1 and Dataset 2

# %%
merged_df=pd.merge(df,df1, on ='instant',how='inner')

# %%
merged_df # merging the 2 dataset in one set
# Out:
#      instant Date of the ride  season  hr        holiday             weekday  \
# 0          1       01-01-2011  Spring   0  Not a holiday         working day
# 1          2       01-01-2011  Spring   1  Not a holiday         working day
# 2          3       01-01-2011  Spring   2  Not a holiday         working day
# 3          4       01-01-2011  Spring   3  Not a holiday         working day
# 4          5       01-01-2011  Spring   4  Not a holiday         working day
# ..       ...              ...     ...  ..            ...                 ...
# 605      606       28-01-2011  Spring  11  Not a holiday  weekend or holiday
# 606      607       28-01-2011  Spring  12  Not a holiday  weekend or holiday
# 607      608       28-01-2011  Spring  13  Not a holiday  weekend or holiday
# 608      609       28-01-2011  Spring  14  Not a holiday  weekend or holiday
# 609      610       28-01-2011  Spring  15  Not a holiday  weekend or holiday
#
# ...

# %%
merged_df.to_csv('merged_dataset.csv',index= False)

# %%
merged_df.nunique()
# Out:
# instant             610
# Date of the ride     28
# season                1
# hr                   24
# holiday               2
# weekday               2
# weathersit            4
# temp                 23
# atemp                30
# hum                  59
# windspeed            20
# casual               32
# registered          150
# Total rentals       165
# dtype: int64

# %% [markdown]
# ## Data summery

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instant           610 non-null    int64
#  1   Date of the ride  610 non-null    object
#  2   season            610 non-null    object
#  3   hr                610 non-null    int64
#  4   holiday           610 non-null    object
#  5   weekday           610 non-null    object
#  6   weathersit        610 non-null    object
#  7   temp              610 non-null    object
#  8   atemp             610 non-null    float64
#  9   hum               610 non-null    object
#  10  windspeed         610 non-null    float64
#  11  casual            610 non-null    int64
#  12  registered        610 non-null    int64
#  13  Total rentals     610 non-null    int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 71.5+ KB

# %%
merged_df.describe() # here we are provide statistics for numerical column in dataframe
# Out:
#           instant          hr       atemp   windspeed      casual  registered  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000   11.795082    0.199935    0.204851    4.501639   51.068852
# std    176.236111    6.852107    0.078120    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    153.250000    6.000000    0.151500    0.104500    0.000000   14.000000
# 50%    305.500000   12.000000    0.197000    0.194000    2.000000   43.000000
# 75%    457.750000   18.000000    0.227300    0.283600    6.000000   70.000000
# max    610.000000   23.000000    0.454500    0.582100   47.000000  247.000000
#
#        Total rentals
# count     610.000000
# mean       55.570492
# std        49.316802
# min         1.000000
# 25%        16.000000
# 50%        47.000000
# 75%        79.750000
# max       249.000000

# %% [markdown]
# ## Missing Values

# %%
missing_values=merged_df.isnull().sum()

# %%
missing_values
# Out:
# instant             0
# Date of the ride    0
# season              0
# hr                  0
# holiday             0
# weekday             0
# weathersit          0
# temp                0
# atemp               0
# hum                 0
# windspeed           0
# casual              0
# registered          0
# Total rentals       0
# dtype: int64

# %% [markdown]
# # Dataset 3

# %%
data3=pd.read_csv('dataset_3.csv')

# %%
data3
# Out:
#          dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 620  29-01-2011       1   0     1   1    False        6           1  0.22
# 621  29-01-2011       1   0     1   2    False        6           1  0.22
# 622  29-01-2011       1   0     1   3    False        6           1  0.20
# 623  29-01-2011       1   0     1   4    False        6           1  0.16
# 624  29-01-2011       1   0     1   6    False        6           1  0.16
# ..          ...     ...  ..   ...  ..      ...      ...         ...   ...
# 615  28-01-2011       1   0     1  20    False        5           2  0.24
# 616  28-01-2011       1   0     1  21    False        5           2  0.22
# 617  28-01-2011       1   0     1  22    False        5           1  0.24
# 618  28-01-2011       1   0     1  23    False        5           1  0.24
# 619  29-01-2011       1   0     1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
df2 = pd.DataFrame(data3)

# %%
df2
# Out:
#          dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 620  29-01-2011       1   0     1   1    False        6           1  0.22
# 621  29-01-2011       1   0     1   2    False        6           1  0.22
# 622  29-01-2011       1   0     1   3    False        6           1  0.20
# 623  29-01-2011       1   0     1   4    False        6           1  0.16
# 624  29-01-2011       1   0     1   6    False        6           1  0.16
# ..          ...     ...  ..   ...  ..      ...      ...         ...   ...
# 615  28-01-2011       1   0     1  20    False        5           2  0.24
# 616  28-01-2011       1   0     1  21    False        5           2  0.22
# 617  28-01-2011       1   0     1  22    False        5           1  0.24
# 618  28-01-2011       1   0     1  23    False        5           1  0.24
# 619  29-01-2011       1   0     1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # Head

# %%
df2.head()
# Out:
#          dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 620  29-01-2011       1   0     1   1    False        6           1  0.22
# 621  29-01-2011       1   0     1   2    False        6           1  0.22
# 622  29-01-2011       1   0     1   3    False        6           1  0.20
# 623  29-01-2011       1   0     1   4    False        6           1  0.16
# 624  29-01-2011       1   0     1   6    False        6           1  0.16
#
#       atemp   hum  windspeed  casual  registered  cnt
# 620  0.2273  0.64     0.1940       0          20   20
# 621  0.2273  0.64     0.1642       0          15   15
# 622  0.2121  0.64     0.1343       3           5    8
# 623  0.1818  0.69     0.1045       1           2    3
# 624  0.1818  0.64     0.1343       0           2    2

# %% [markdown]
# # Tail

# %%
df2.tail()
# Out:
#          dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 615  28-01-2011       1   0     1  20    False        5           2  0.24
# 616  28-01-2011       1   0     1  21    False        5           2  0.22
# 617  28-01-2011       1   0     1  22    False        5           1  0.24
# 618  28-01-2011       1   0     1  23    False        5           1  0.24
# 619  29-01-2011       1   0     1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# 615  0.2273  0.70     0.1940       1          61   62
# 616  0.2273  0.75     0.1343       1          57   58
# 617  0.2121  0.65     0.3582       0          26   26
# 618  0.2273  0.60     0.2239       1          22   23
# 619  0.1970  0.64     0.3582       2          26   28

# %% [markdown]
# # Data type

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 390 entries, 620 to 619
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      390 non-null    object
#  1   season      390 non-null    int64
#  2   yr          390 non-null    int64
#  3   mnth        390 non-null    int64
#  4   hr          390 non-null    int64
#  5   holiday     390 non-null    bool
#  6   weekday     390 non-null    int64
#  7   weathersit  390 non-null    int64
#  8   temp        390 non-null    float64
#  9   atemp       390 non-null    float64
#  10  hum         390 non-null    float64
#  11  windspeed   390 non-null    float64
#  12  casual      390 non-null    int64
#  13  registered  390 non-null    int64
#  14  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(9), object(1)
# memory usage: 46.1+ KB

# %% [markdown]
# # summary

# %%
df2.describe().round(2)
# Out:
#        season     yr   mnth      hr  weekday  weathersit    temp   atemp  \
# count   390.0  390.0  390.0  390.00   390.00      390.00  390.00  390.00
# mean      1.0    0.0    1.8   11.69     2.99        1.48    0.22    0.23
# std       0.0    0.0    0.4    6.98     2.15        0.66    0.07    0.07
# min       1.0    0.0    1.0    0.00     0.00        1.00    0.06    0.08
# 25%       1.0    0.0    2.0    6.00     1.00        1.00    0.16    0.18
# 50%       1.0    0.0    2.0   12.00     3.00        1.00    0.22    0.23
# 75%       1.0    0.0    2.0   18.00     5.00        2.00    0.26    0.27
# max       1.0    0.0    2.0   23.00     6.00        3.00    0.42    0.42
#
#           hum  windspeed  casual  registered     cnt
# count  390.00     390.00  390.00      390.00  390.00
# mean     0.61       0.18    5.58       57.00   62.58
# std      0.20       0.14    9.32       49.07   53.27
# min      0.21       0.00    0.00        0.00    1.00
# ...

# %% [markdown]
# # dimension

# %%
df2.shape
# Out:
# (390, 15)

# %% [markdown]
# # Date of the ride

# %%
df2.rename(columns={'dteday': 'Date of the ride'}, inplace=True)

# %%
df2
# Out:
#     Date of the ride  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 620       29-01-2011       1   0     1   1    False        6           1
# 621       29-01-2011       1   0     1   2    False        6           1
# 622       29-01-2011       1   0     1   3    False        6           1
# 623       29-01-2011       1   0     1   4    False        6           1
# 624       29-01-2011       1   0     1   6    False        6           1
# ..               ...     ...  ..   ...  ..      ...      ...         ...
# 615       28-01-2011       1   0     1  20    False        5           2
# 616       28-01-2011       1   0     1  21    False        5           2
# 617       28-01-2011       1   0     1  22    False        5           1
# 618       28-01-2011       1   0     1  23    False        5           1
# 619       29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # season 1=Spring

# %%
df2['season']=df2['season'].replace({1:'Spring',2:'Summer',3:'Winter',4: 'Rain'})

# %%
df2
# Out:
#     Date of the ride  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 620       29-01-2011  Spring   0     1   1    False        6           1
# 621       29-01-2011  Spring   0     1   2    False        6           1
# 622       29-01-2011  Spring   0     1   3    False        6           1
# 623       29-01-2011  Spring   0     1   4    False        6           1
# 624       29-01-2011  Spring   0     1   6    False        6           1
# ..               ...     ...  ..   ...  ..      ...      ...         ...
# 615       28-01-2011  Spring   0     1  20    False        5           2
# 616       28-01-2011  Spring   0     1  21    False        5           2
# 617       28-01-2011  Spring   0     1  22    False        5           1
# 618       28-01-2011  Spring   0     1  23    False        5           1
# 619       29-01-2011  Spring   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
df2['holiday'] = df2['holiday'].replace({False:'Not a holiday'})

# %%
df2
# Out:
#     Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 620       29-01-2011  Spring   0     1   1  Not a holiday        6
# 621       29-01-2011  Spring   0     1   2  Not a holiday        6
# 622       29-01-2011  Spring   0     1   3  Not a holiday        6
# 623       29-01-2011  Spring   0     1   4  Not a holiday        6
# 624       29-01-2011  Spring   0     1   6  Not a holiday        6
# ..               ...     ...  ..   ...  ..            ...      ...
# 615       28-01-2011  Spring   0     1  20  Not a holiday        5
# 616       28-01-2011  Spring   0     1  21  Not a holiday        5
# 617       28-01-2011  Spring   0     1  22  Not a holiday        5
# 618       28-01-2011  Spring   0     1  23  Not a holiday        5
# 619       29-01-2011  Spring   0     1   0  Not a holiday        6
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 620           1  0.22  0.2273  0.64     0.1940       0          20   20
# ...

# %% [markdown]
# # humidity- relative humidity

# %%
df2['hum'] = df2['hum'].apply(lambda x: f'{int(x * 100)}%')

# %% [markdown]
# # Weather

# %%
df2['weathersit']=df2['weathersit'].replace({1:'clear,Few clouds,Partly cloudy'})

# %%
df2['weathersit']=df2['weathersit'].replace({2:'Mist+cloudy mis+Broken clouds,Mist+Few clouds'})

# %%
df2['weathersit']=df2['weathersit'].replace({3:'Light snow,Light Rain+Thounderstrom+Scattered clouds'})

# %%
df2['weathersit']=df2['weathersit'].replace({4:'Heavy rain+Ice pallets+Thounders strome+Mist,Snow +fog'})

# %%
df2
# Out:
#     Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 620       29-01-2011  Spring   0     1   1  Not a holiday        6
# 621       29-01-2011  Spring   0     1   2  Not a holiday        6
# 622       29-01-2011  Spring   0     1   3  Not a holiday        6
# 623       29-01-2011  Spring   0     1   4  Not a holiday        6
# 624       29-01-2011  Spring   0     1   6  Not a holiday        6
# ..               ...     ...  ..   ...  ..            ...      ...
# 615       28-01-2011  Spring   0     1  20  Not a holiday        5
# 616       28-01-2011  Spring   0     1  21  Not a holiday        5
# 617       28-01-2011  Spring   0     1  22  Not a holiday        5
# 618       28-01-2011  Spring   0     1  23  Not a holiday        5
# 619       29-01-2011  Spring   0     1   0  Not a holiday        6
#
#                                         weathersit  temp   atemp  hum  \
# 620                 clear,Few clouds,Partly cloudy  0.22  0.2273  64%
# ...

# %% [markdown]
# # Drop unnecessary column

# %%
df2=df2.drop(['yr','mnth'],axis=1)

# %%
df2
# Out:
#     Date of the ride  season  hr        holiday  weekday  \
# 620       29-01-2011  Spring   1  Not a holiday        6
# 621       29-01-2011  Spring   2  Not a holiday        6
# 622       29-01-2011  Spring   3  Not a holiday        6
# 623       29-01-2011  Spring   4  Not a holiday        6
# 624       29-01-2011  Spring   6  Not a holiday        6
# ..               ...     ...  ..            ...      ...
# 615       28-01-2011  Spring  20  Not a holiday        5
# 616       28-01-2011  Spring  21  Not a holiday        5
# 617       28-01-2011  Spring  22  Not a holiday        5
# 618       28-01-2011  Spring  23  Not a holiday        5
# 619       29-01-2011  Spring   0  Not a holiday        6
#
#                                         weathersit  \
# 620                 clear,Few clouds,Partly cloudy
# 621                 clear,Few clouds,Partly cloudy
# 622                 clear,Few clouds,Partly cloudy
# 623                 clear,Few clouds,Partly cloudy
# ...

# %% [markdown]
# # central tendency of windspeed

# %%
df2['windspeed'].mean()
# Out:
# 0.17941589743589745

# %%
df2['windspeed'].median()
# Out:
# 0.1642

# %%
df2['windspeed'].mode()
# Out:
# 0    0.0
# Name: windspeed, dtype: float64

# %% [markdown]
# # casual number of non-registered user rentals initiated

# %% [markdown]
# # unique values of non registered user rentals

# %%
df2['casual'].unique()
# Out:
# array([ 0,  3,  1,  4, 12,  9, 10, 22, 19,  6,  7, 13, 18, 14,  8,  2,  5,
#        15, 11, 28, 48, 47, 52, 42, 24, 16, 21, 17, 30, 27, 32, 26, 58, 62,
#        51, 40], dtype=int64)

# %%
df2['casual'].mean()
# Out:
# 5.576923076923077

# %%
df2['casual'].median()
# Out:
# 3.0

# %%
df2['casual'].mode()
# Out:
# 0    0
# Name: casual, dtype: int64

# %% [markdown]
# # registered number of registered user rentals initiated

# %% [markdown]
# # unique values of registered user rentals

# %%
df2['registered'].unique()
# Out:
# array([ 20,  15,   5,   2,   4,  31,  34,  51,  60,  66,  56,  89,  98,
#         88,  82,  59,  52,  42,  35,  28,  30,  33,  22,  10,   7,   1,
#          3,  11,  57,  50,  87,  71, 104,  95,  46,  25,  19,  16,   6,
#          8,  37, 182, 112,  68,  62,  85,  41,  83, 155, 153, 108,  78,
#         53, 132, 114,  47,  49,  45,  61, 172, 165, 105,  69,  64,   0,
#         17,  48, 154, 119,  74, 183, 175,  29,  39,  86, 184, 127,  55,
#         67,  43,  73, 170, 145,  92,  26, 217, 124,  76,  81,  91, 195,
#        152, 102,  36,  12,   9,  63,  40,  21,  38, 126, 135, 130, 115,
#         97,  65,  14, 223,  54, 207, 123,  75, 236, 128,  44,  79, 151,
#        100, 198,  72, 157, 168,  84,  99, 173, 121, 159, 110,  93,  70,
#         23, 212, 111, 193,  94,  27,  13, 103,  90, 113, 122, 106,  32,
#         96, 147, 107], dtype=int64)

# %% [markdown]
# # central tendency of registered user rentals

# %%
df2['registered'].mean()
# Out:
# 57.0025641025641

# %%
df2['registered'].median()
# Out:
# 48.0

# %%
df2['registered'].mode()
# Out:
# 0    1
# Name: registered, dtype: int64

# %% [markdown]
# # count-number of total rentals

# %% [markdown]
# # unique values of total rentals

# %%
df2['cnt'].unique()
# Out:
# array([ 20,  15,   8,   3,   2,   5,  34,  55,  64,  78,  65,  99, 120,
#        107,  91,  68,  58,  43,  36,  32,  33,  29,  11,   1,  12,  38,
#         59,  97,  84, 122, 109, 123,  77,  28,  21,   7,  37,  72, 185,
#        112,  69,  48,  54,  86,  44, 161, 156, 111,  56,  17,  22,  52,
#        135, 116,  47,  51, 176, 168, 108,  74,  16,   4,  18,  49, 155,
#         61,  75,  63,  76, 103, 190, 182,  40,  39,  87, 188, 133,  60,
#        175, 147,  96,  41,  13, 220, 127,  82,  90, 205,  71,  46,  31,
#          9,  10,  83,  45,  23,  89, 117, 174, 157, 121,  26,  27,  62,
#         30,  95, 230, 118,  66,  50, 114, 216, 128,  88,  25, 100, 243,
#        152, 101, 199,  79, 166, 170,   6, 178,  35,  80, 165, 160,  14,
#         24, 140, 110, 125, 211,  53, 145, 137, 105, 154, 162, 134,  98,
#        149], dtype=int64)

# %%
df2['cnt'].mean()
# Out:
# 62.57948717948718

# %%
df2['cnt'].median()
# Out:
# 52.0

# %%
df2['cnt'].mode()
# Out:
# 0    2
# Name: cnt, dtype: int64

# %%
df2.rename(columns={'cnt':'Total rentals'}, inplace=True)

# %% [markdown]
# # Missing values of dataset 3

# %%
df2.isnull().sum()
# Out:
# Date of the ride    0
# season              0
# hr                  0
# holiday             0
# weekday             0
# weathersit          0
# temp                0
# atemp               0
# hum                 0
# windspeed           0
# casual              0
# registered          0
# Total rentals       0
# dtype: int64

# %%
df2['atemp'].mean()
# Out:
# 0.23042384615384612

# %%
df2['atemp'].median()
# Out:
# 0.2273

# %%
df2['atemp'].mode()
# Out:
# 0    0.2273
# Name: atemp, dtype: float64

# %%
df2
# Out:
#     Date of the ride  season  hr        holiday  weekday  \
# 620       29-01-2011  Spring   1  Not a holiday        6
# 621       29-01-2011  Spring   2  Not a holiday        6
# 622       29-01-2011  Spring   3  Not a holiday        6
# 623       29-01-2011  Spring   4  Not a holiday        6
# 624       29-01-2011  Spring   6  Not a holiday        6
# ..               ...     ...  ..            ...      ...
# 615       28-01-2011  Spring  20  Not a holiday        5
# 616       28-01-2011  Spring  21  Not a holiday        5
# 617       28-01-2011  Spring  22  Not a holiday        5
# 618       28-01-2011  Spring  23  Not a holiday        5
# 619       29-01-2011  Spring   0  Not a holiday        6
#
#                                         weathersit  \
# 620                 clear,Few clouds,Partly cloudy
# 621                 clear,Few clouds,Partly cloudy
# 622                 clear,Few clouds,Partly cloudy
# 623                 clear,Few clouds,Partly cloudy
# ...

# %% [markdown]
# # Concatenate all Datasets

# %%
Comp_dataset = pd.concat([merged_df,df2])

# %%
Comp_dataset # concat all dataset 1,dataset2 & dataset 3
# Out:
#      instant Date of the ride  season  hr        holiday      weekday  \
# 0        1.0       01-01-2011  Spring   0  Not a holiday  working day
# 1        2.0       01-01-2011  Spring   1  Not a holiday  working day
# 2        3.0       01-01-2011  Spring   2  Not a holiday  working day
# 3        4.0       01-01-2011  Spring   3  Not a holiday  working day
# 4        5.0       01-01-2011  Spring   4  Not a holiday  working day
# ..       ...              ...     ...  ..            ...          ...
# 615      NaN       28-01-2011  Spring  20  Not a holiday            5
# 616      NaN       28-01-2011  Spring  21  Not a holiday            5
# 617      NaN       28-01-2011  Spring  22  Not a holiday            5
# 618      NaN       28-01-2011  Spring  23  Not a holiday            5
# 619      NaN       29-01-2011  Spring   0  Not a holiday            6
#
#                                         weathersit  \
# 0                   clear,few,clouds,partly cloudy
# ...

# %%
Comp_dataset.isnull().sum()
# Out:
# instant             390
# Date of the ride      0
# season                0
# hr                    0
# holiday               0
# weekday               0
# weathersit            0
# temp                  0
# atemp                 0
# hum                   0
# windspeed             0
# casual                0
# registered            0
# Total rentals         0
# dtype: int64

# %%
Comp_dataset['instant'].mean()
# Out:
# 305.5

# %%
Comp_dataset['instant'].fillna(Comp_dataset['instant'].mean(),inplace=True)

# %%
Comp_dataset.isnull().sum()
# Out:
# instant             0
# Date of the ride    0
# season              0
# hr                  0
# holiday             0
# weekday             0
# weathersit          0
# temp                0
# atemp               0
# hum                 0
# windspeed           0
# casual              0
# registered          0
# Total rentals       0
# dtype: int64

# %%
Q1 = Comp_dataset['Total rentals'].quantile(0.25)
Q3 = Comp_dataset['Total rentals'].quantile(0.75)


Iqr = Q3 - Q1

min_r = Q1 - 1.5 * Iqr
max_r = Q3 + 1.5 * Iqr

outliers=Comp_dataset.index[(Comp_dataset['Total rentals'] < min_r) | (Comp_dataset['Total rentals'] > max_r)]

# %%
outliers
# Out:
# Int64Index([ 85,  99, 108, 122, 145, 154, 217, 239, 285, 415, 424, 439, 448,
#             449, 463, 541, 555, 564, 565, 673, 729, 743, 766, 775, 838, 847,
#             862, 885, 930, 939],
#            dtype='int64')

# %% [markdown]
# # Removing outliers

# %%
Comp_dataset_no_outliers= Comp_dataset.drop(outliers)

# %%
Comp_dataset_no_outliers
# Out:
#      instant Date of the ride  season  hr        holiday      weekday  \
# 0        1.0       01-01-2011  Spring   0  Not a holiday  working day
# 1        2.0       01-01-2011  Spring   1  Not a holiday  working day
# 2        3.0       01-01-2011  Spring   2  Not a holiday  working day
# 3        4.0       01-01-2011  Spring   3  Not a holiday  working day
# 4        5.0       01-01-2011  Spring   4  Not a holiday  working day
# ..       ...              ...     ...  ..            ...          ...
# 615    305.5       28-01-2011  Spring  20  Not a holiday            5
# 616    305.5       28-01-2011  Spring  21  Not a holiday            5
# 617    305.5       28-01-2011  Spring  22  Not a holiday            5
# 618    305.5       28-01-2011  Spring  23  Not a holiday            5
# 619    305.5       29-01-2011  Spring   0  Not a holiday            6
#
#                                         weathersit  \
# 0                   clear,few,clouds,partly cloudy
# ...

# %% [markdown]
# # Skewness & correlation of final data

# %%
skewness_rows = Comp_dataset_no_outliers.skew()
# Out:
# C:\Users\Sonali\AppData\Local\Temp\ipykernel_37744\3696799826.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skewness_rows = Comp_dataset_no_outliers.skew()

# %%
skewness_rows
# Out:
# instant         -0.003209
# hr              -0.064571
# atemp            0.446291
# windspeed        0.432567
# casual           3.425211
# registered       0.947195
# Total rentals    0.851761
# dtype: float64

# %%
skewness_col = Comp_dataset_no_outliers.skew(axis=1)
# Out:
# C:\Users\Sonali\AppData\Local\Temp\ipykernel_37744\468581601.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   skewness_col = Comp_dataset_no_outliers.skew(axis=1)

# %%
skewness_col
# Out:
# 0      1.206115
# 1      1.208119
# 2      1.213267
# 3      0.977739
# 4      1.141424
#          ...
# 615    2.319573
# 616    2.359434
# 617    2.578288
# 618    2.591013
# 619    2.579350
# Length: 970, dtype: float64

# %%
correlation = Comp_dataset_no_outliers.corr()
# Out:
# C:\Users\Sonali\AppData\Local\Temp\ipykernel_37744\968359679.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = Comp_dataset_no_outliers.corr()

# %%
correlation
# Out:
#                 instant        hr     atemp  windspeed    casual  registered  \
# instant        1.000000  0.016018 -0.229610  -0.020755 -0.058489    0.025664
# hr             0.016018  1.000000  0.137481   0.121980  0.202303    0.429842
# atemp         -0.229610  0.137481  1.000000  -0.212058  0.423239    0.150736
# windspeed     -0.020755  0.121980 -0.212058   1.000000  0.135106    0.118549
# casual        -0.058489  0.202303  0.423239   0.135106  1.000000    0.385155
# registered     0.025664  0.429842  0.150736   0.118549  0.385155    1.000000
# Total rentals  0.013385  0.430639  0.212554   0.132623  0.528884    0.986921
#
#                Total rentals
# instant             0.013385
# hr                  0.430639
# atemp               0.212554
# windspeed           0.132623
# casual              0.528884
# registered          0.986921
# Total rentals       1.000000

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >
